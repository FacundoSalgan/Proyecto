# %% [markdown]
# <a href="https://colab.research.google.com/github/FacundoSalgan/Proyecto/blob/main/Dataset%2Bsalgan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/FacundoSalgan/Proyecto/refs/heads/main/pandora_dataset.csv"
df = pd.read_csv(url)

# Mostrar las primeras filas del dataset
df.head()
# Out:
#   Song ID   Title    Artist    Album      Genre  Release Year  Duration (sec)  \
# 0   PAN_0  Song 0  Artist 0  Album 0    Country          2009             344
# 1   PAN_1  Song 1  Artist 1  Album 1       Jazz          2014             362
# 2   PAN_2  Song 2  Artist 2  Album 2  Classical          2001             262
# 3   PAN_3  Song 3  Artist 3  Album 3    Country          1998             160
# 4   PAN_4  Song 4  Artist 4  Album 4    Hip-Hop          2020             377
#
#    Popularity  Streams/Views (Millions) Language  Country Platform  \
# 0          22                     49.39   French  Germany  Pandora
# 1          57                     28.80  Spanish   Canada  Pandora
# 2          84                     65.48  English   Canada  Pandora
# 3          27                     29.81   Korean   Brazil  Pandora
# 4          41                    422.66  Spanish  Germany  Pandora
#
#   Playlist Name Listener Age Group  User Rating  Comments Count
# ...

# %%
# Información general del dataset
df.info()

# Estadísticas generales de las variables numéricas
df.describe()

# Revisar valores nulos
df.isnull().sum()

# Acceder a las columnas individualmente:
df['Genre'].head()
df['Release Year'].head()
df['Duration (sec)'].head()
df['Popularity'].head()
df['Streams/Views (Millions)'].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Song ID                   2000 non-null   object
#  1   Title                     2000 non-null   object
#  2   Artist                    2000 non-null   object
#  3   Album                     2000 non-null   object
#  4   Genre                     2000 non-null   object
#  5   Release Year              2000 non-null   int64
#  6   Duration (sec)            2000 non-null   int64
#  7   Popularity                2000 non-null   int64
#  8   Streams/Views (Millions)  2000 non-null   float64
#  9   Language                  2000 non-null   object
#  10  Country                   2000 non-null   object
#  11  Platform                  2000 non-null   object
#  12  Playlist Name             2000 non-null   object
# ...

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/FacundoSalgan/Proyecto/refs/heads/main/spotify_dataset.csv"
df = pd.read_csv(url)

# Mostrar las primeras filas del dataset
df.head()
# Out:
#   Song ID   Title    Artist    Album      Genre  Release Year  Duration (sec)  \
# 0   SPO_0  Song 0  Artist 0  Album 0    Country          2009             344
# 1   SPO_1  Song 1  Artist 1  Album 1       Jazz          2014             362
# 2   SPO_2  Song 2  Artist 2  Album 2  Classical          2001             262
# 3   SPO_3  Song 3  Artist 3  Album 3    Country          1998             160
# 4   SPO_4  Song 4  Artist 4  Album 4    Hip-Hop          2020             377
#
#    Popularity  Streams/Views (Millions) Language  Country Platform  \
# 0          22                     49.39   French  Germany  Spotify
# 1          57                     28.80  Spanish   Canada  Spotify
# 2          84                     65.48  English   Canada  Spotify
# 3          27                     29.81   Korean   Brazil  Spotify
# 4          41                    422.66  Spanish  Germany  Spotify
#
#   Playlist Name Listener Age Group  User Rating  Comments Count
# ...

# %%
# Información general del dataset
df.info()

# Estadísticas generales de las variables numéricas
df.describe()

# Revisar valores nulos
df.isnull().sum()

# Acceder a las columnas individualmente:
df['Genre'].head()
df['Release Year'].head()
df['Duration (sec)'].head()
df['Popularity'].head()
df['Streams/Views (Millions)'].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Song ID                   2000 non-null   object
#  1   Title                     2000 non-null   object
#  2   Artist                    2000 non-null   object
#  3   Album                     2000 non-null   object
#  4   Genre                     2000 non-null   object
#  5   Release Year              2000 non-null   int64
#  6   Duration (sec)            2000 non-null   int64
#  7   Popularity                2000 non-null   int64
#  8   Streams/Views (Millions)  2000 non-null   float64
#  9   Language                  2000 non-null   object
#  10  Country                   2000 non-null   object
#  11  Platform                  2000 non-null   object
#  12  Playlist Name             2000 non-null   object
# ...

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/FacundoSalgan/Proyecto/refs/heads/main/youtube_dataset.csv"
df = pd.read_csv(url)

# Mostrar las primeras filas del dataset
df.head()
# Out:
#   Song ID   Title    Artist    Album      Genre  Release Year  Duration (sec)  \
# 0   YOU_0  Song 0  Artist 0  Album 0    Country          2009             344
# 1   YOU_1  Song 1  Artist 1  Album 1       Jazz          2014             362
# 2   YOU_2  Song 2  Artist 2  Album 2  Classical          2001             262
# 3   YOU_3  Song 3  Artist 3  Album 3    Country          1998             160
# 4   YOU_4  Song 4  Artist 4  Album 4    Hip-Hop          2020             377
#
#    Popularity  Streams/Views (Millions) Language  Country Platform  \
# 0          22                     49.39   French  Germany  YouTube
# 1          57                     28.80  Spanish   Canada  YouTube
# 2          84                     65.48  English   Canada  YouTube
# 3          27                     29.81   Korean   Brazil  YouTube
# 4          41                    422.66  Spanish  Germany  YouTube
#
#   Playlist Name Listener Age Group  User Rating  Comments Count
# ...

# %%
# Información general del dataset
df.info()

# Estadísticas generales de las variables numéricas
df.describe()

# Revisar valores nulos
df.isnull().sum()

# Acceder a las columnas individualmente:
df['Genre'].head()
df['Release Year'].head()
df['Duration (sec)'].head()
df['Popularity'].head()
df['Streams/Views (Millions)'].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Song ID                   2000 non-null   object
#  1   Title                     2000 non-null   object
#  2   Artist                    2000 non-null   object
#  3   Album                     2000 non-null   object
#  4   Genre                     2000 non-null   object
#  5   Release Year              2000 non-null   int64
#  6   Duration (sec)            2000 non-null   int64
#  7   Popularity                2000 non-null   int64
#  8   Streams/Views (Millions)  2000 non-null   float64
#  9   Language                  2000 non-null   object
#  10  Country                   2000 non-null   object
#  11  Platform                  2000 non-null   object
#  12  Playlist Name             2000 non-null   object
# ...

# %% [markdown]
# # Analisis de variables
#
# ## 1. "Streams / Plays"
# Cantidad de reproducciones de una canción.
#
# ## 2. "likes / ratings"
# Indicador del gusto del público.
#
# ## 3. "Ranking"
# Posición en los charts de la plataforma.
